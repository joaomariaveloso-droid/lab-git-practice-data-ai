# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Your Name Here"
reason = "Why you are interested in AI, Data Analytics, or Data Science"
fun_fact = "One fun fact about yourself or a goal for this course"

print(f"Hi! My name is João Monteiro. I’m excited to learn because i want to dive into data analytics, i have always been fascinated about this subject and want to make a career out of it. A fun fact about me is: i used to be a farmer.")
# Out:
# Hi! My name is João Monteiro. I’m excited to learn because i want to dive into data analytics, i have always been fascinated about this subject and want to make a career out of it. A fun fact about me is: i used to be a farmer.
